# %% [markdown]
# # Project

# %% [markdown]
# ## Estadística de Producción Agrícola

# %%
import pandas as pd
import numpy as np
from numpy import NaN
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introducción:
#
# El proposito de este analisis es....

# %%
data_2020 = pd.read_csv("data/project_v4/data/Cierre_agricola_mun_2020.csv", 
                        encoding="latin1")

data_2020.head()
# Out:
#    Anio  Idestado       Nomestado  Idddr          Nomddr  Idcader  \
# 0  2020         1  Aguascalientes      1  Aguascalientes        1
# 1  2020         1  Aguascalientes      1  Aguascalientes        1
# 2  2020         1  Aguascalientes      1  Aguascalientes        1
# 3  2020         1  Aguascalientes      1  Aguascalientes        1
# 4  2020         1  Aguascalientes      1  Aguascalientes        1
#
#          Nomcader  Idmunicipio    Nommunicipio  Idciclo  ... Nomunidad  \
# 0  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 1  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 2  Aguascalientes            1  Aguascalientes        2  ...  Tonelada
# 3  Aguascalientes            1  Aguascalientes        2  ...  Tonelada
# 4  Aguascalientes            1  Aguascalientes        2  ...  Tonelada
#
#    Idcultivo         Nomcultivo Sin Um  Sembrada Cosechada  Siniestrada  \
# ...

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28661 entries, 0 to 28660
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Anio                28661 non-null  int64
#  1   Idestado            28661 non-null  int64
#  2   Nomestado           28661 non-null  object
#  3   Idddr               28661 non-null  int64
#  4   Nomddr              28661 non-null  object
#  5   Idcader             28661 non-null  int64
#  6   Nomcader            28661 non-null  object
#  7   Idmunicipio         28661 non-null  int64
#  8   Nommunicipio        28661 non-null  object
#  9   Idciclo             28661 non-null  int64
#  10  Nomcicloproductivo  28661 non-null  object
#  11  Idmodalidad         28661 non-null  int64
#  12  Nommodalidad        28661 non-null  object
#  13  Idunidadmedida      28661 non-null  int64
#  14  Nomunidad           28661 non-null  object
# ...

# %%
data_2019 = pd.read_csv("https://raw.githubusercontent.com/IA-Center-Python/project_ds_python_v4-alanponce/main/data/Cierre_agricola_mun_2019.csv?token=GHSAT0AAAAAAB3ADV76LDPFGO2DODQXLQYKY63CZDA",
                       encoding="latin1")

data_2019.head()
# Out:
#    Anio  Idestado       Nomestado  Idddr          Nomddr  Idcader  \
# 0  2019         1  Aguascalientes      1  Aguascalientes        1
# 1  2019         1  Aguascalientes      1  Aguascalientes        1
# 2  2019         1  Aguascalientes      1  Aguascalientes        1
# 3  2019         1  Aguascalientes      1  Aguascalientes        1
# 4  2019         1  Aguascalientes      1  Aguascalientes        1
#
#          Nomcader  Idmunicipio    Nommunicipio  Idciclo  ... Nomunidad  \
# 0  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 1  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 2  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 3  Aguascalientes            1  Aguascalientes        1  ...  Tonelada
# 4  Aguascalientes            1  Aguascalientes        2  ...  Tonelada
#
#    Idcultivo             Nomcultivo Sin Um  Sembrada Cosechada  Siniestrada  \
# ...

# %% [markdown]
# ## Analsis Exploratorio

# %% [markdown]
# El objetivo de este analisis es x, y z.
#
#
# Nos focalizaremos primeramente en identificar cuales son los paises participantes de esta encuesta

# %%
data_2020["Nomestado"].value_counts()
# Out:
# Oaxaca                 4374
# Puebla                 2663
# Jalisco                1788
# Veracruz               1736
# Michoacán              1713
# México                 1527
# Guerrero               1341
# Guanajuato             1220
# Hidalgo                1015
# Sonora                  963
# Chiapas                 956
# Zacatecas               918
# San Luis Potosí         825
# Chihuahua               770
# Tlaxcala                708
# Morelos                 679
# Sinaloa                 670
# Yucatán                 662
# Durango                 605
# Tamaulipas              541
# Nayarit                 436
# Coahuila                384
# Querétaro               310
# Nuevo León              294
# Aguascalientes          254
# Colima                  242
# Tabasco                 224
# Campeche                218
# Baja California         215
# Quintana Roo            149
# Baja California Sur     148
# Ciudad de México        113
# Name: Nomestado, dtype: int64

# %% [markdown]
# Podemos apreciar que este conjunto de datos tenemos .....

# %% [markdown]
# ## Resultados:
#
# En esta sección se plantearán los resultados de su análisis......

# %% [markdown]
# ## Conclusion:
#
# En esta sección se indicarán sus conclusiones....

# %% [markdown]
# ## Referencias:
